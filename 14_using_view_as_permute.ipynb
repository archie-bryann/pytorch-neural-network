# %%
import torch

# %%
x = torch.tensor([[1,2,3],[4,5,6]])
print(x)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
print(x.view(3, 2)) # this is view -> whatever is most convinient
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
print(x.permute(1,0)) # this is transpose
# Out:
# tensor([[1, 4],
#         [2, 5],
#         [3, 6]])
