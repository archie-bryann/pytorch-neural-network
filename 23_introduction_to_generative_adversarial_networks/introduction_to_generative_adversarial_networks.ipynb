# %%
# Generative Adversarial Networks (GANs)
# Types: Style-Based GAN, Super Resolution GAN (SRGAN)
# Nvidia DLSS (heavily built on GANs)
# Cool Applications: CycleGan & pix2pix in Pytorch
# GANs are also used in: Data Augmentation, Medical Applications (privacy), Semi-supervised Learning (SGAN)

# %%
# What are GANs
# A class of machine learning techniques tht consists of two networks playing an adversarial game against each other
# Networks: The Generator (Counterfeeder) & The Discriminator (Detective)

# %%
# Why does this work?
# In the end the Generator generates dollar bills indistinguishable from real ones and the Discriminator 
# is forced to guess (with probability = 1/2)

# Note: Both the Discriminator and Generator actually start from scratch meaning that they are both
# randomly initalized at start and then simultaneously trained

# %%
from IPython.display import Image, display

# What's the loss function?

# Discriminator
img = Image(filename='discriminator.png')  # local file
display(img)

# Question: Does the discriminator want to maximize or minimize this?
# Correct answer: Maximize

# %%
# What's the loss function?

# Generator
img = Image(filename='generator.png')  # local file
display(img)

# Question: Does the Generator want to maximize or minimize this?
# Correct answer: Minimize

# %%
# Putting the loss together

img = Image(filename='together.png')  # local file
display(img)
